# %% [markdown]
# ## Logistic Regression
# $$ g\big(x\big) = \frac{1}{1 + e^{-(w.x + b)}} $$

# %%
import numpy as np
from modules.models.logistic_regression import *
from modules.eda_functions import *

# %%
path = '../data/lags/'

# %%
all_data_as_dict = import_all_files_as_dict(path)

# %%
all_data_as_dict
# Out:
# {'ABEO':               Close  lag_1 label
#  Date
#  2021-10-20  22.5000  22.50  down
#  2021-10-21  22.5000  22.50  down
#  2021-10-22  21.5000  22.50    up
#  2021-10-25  21.0000  21.50    up
#  2021-10-26  22.0000  21.00  down
#  ...             ...    ...   ...
#  2021-10-13  22.0000  22.50    up
#  2021-10-14  22.2500  22.00  down
#  2021-10-15  22.7500  22.25  down
#  2021-10-18  22.2500  22.75    up
#  2022-08-19   4.2508  22.25    up
#
#  [1258 rows x 3 columns],
#  'ABIO':              Close  lag_1 label
#  Date
#  2021-10-20  2.7600   2.74  down
#  2021-10-21  2.7700   2.76  down
#  2021-10-22  2.6700   2.77    up
#  2021-10-25  2.7000   2.67  down
#  2021-10-26  2.6900   2.70    up
#  ...            ...    ...   ...
#  2021-10-13  2.8700   2.75  down
#  2021-10-14  2.8300   2.87    up
#  2021-10-15  2.7900   2.83    up
#  2021-10-18  2.7300   2.79    up
#  2022-08-19  2.3226   2.73    up
#
#  [1258 rows x 3 columns],
#  'ABUS':             Close  lag_1 label
#  Date
#  2021-10-20   4.09   4.15    up
#  2021-10-21   4.11   4.09  down
#  2021-10-22   4.03   4.11    up
#  2021-10-25   4.03   4.03  down
#  2021-10-26   4.07   4.03  down
#  ...           ...    ...   ...
#  2021-10-13   4.16   4.23    up
#  2021-10-14   4.15   4.16    up
#  2021-10-15   4.08   4.15    up
#  2021-10-18   4.14   4.08  down
#  2022-08-19   2.32   4.14    up
#
#  [1258 rows x 3 columns],
#  'ACAD':                 Close      lag_1 label
#  Date
#  2021-10-20  17.980000  17.690001  down
#  2021-10-21  18.049999  17.980000  down
#  2021-10-22  18.540001  18.049999  down
#  2021-10-25  17.360001  18.540001    up
#  2021-10-26  17.559999  17.360001  down
#  ...               ...        ...   ...
#  2021-10-13  17.840000  17.629999  down
#  2021-10-14  17.820000  17.840000    up
#  2021-10-15  17.510000  17.820000    up
#  2021-10-18  17.600000  17.510000  down
#  2022-08-19  16.780001  17.600000    up
#
#  [1258 rows x 3 columns],
#  'ACER':             Close  lag_1 label
#  Date
#  2021-10-20   2.42   2.40  down
#  2021-10-21   2.42   2.42  down
#  2021-10-22   2.37   2.42    up
#  2021-10-25   2.34   2.37    up
#  2021-10-26   2.39   2.34  down
#  ...           ...    ...   ...
#  2021-10-13   2.50   2.47  down
#  2021-10-14   2.50   2.50  down
#  2021-10-15   2.43   2.50    up
#  2021-10-18   2.39   2.43    up
#  2022-08-19   1.47   2.39    up
#
#  [1258 rows x 3 columns],
#  'ACHN':             Close  lag_1 label
#  Date
#  2021-10-20   0.51   0.51  down
#  2021-10-21   0.48   0.51    up
#  2021-10-22   0.48   0.48  down
#  2021-10-25   0.48   0.48  down
#  2021-10-26   0.41   0.48    up
#  ...           ...    ...   ...
#  2022-08-12   0.25   0.25  down
#  2022-08-15   0.25   0.25  down
#  2022-08-16   0.25   0.25  down
#  2022-08-17   0.25   0.25  down
#  2022-08-18   0.25   0.25  down
#
#  [209 rows x 3 columns],
#  'ACHV':             Close  lag_1 label
#  Date
#  2021-10-20  8.190   7.97  down
#  2021-10-21  8.130   8.19    up
#  2021-10-22  8.020   8.13    up
#  2021-10-25  8.100   8.02  down
#  2021-10-26  8.130   8.10  down
#  ...           ...    ...   ...
#  2021-10-13  8.210   8.41    up
#  2021-10-14  8.300   8.21  down
#  2021-10-15  8.050   8.30    up
#  2021-10-18  7.890   8.05    up
#  2022-08-19  4.935   7.89    up
#
#  [1258 rows x 3 columns],
#  'ACIU':             Close  lag_1 label
#  Date
#  2021-10-20   6.05   6.04  down
#  2021-10-21   6.04   6.05    up
#  2021-10-22   6.03   6.04    up
#  2021-10-25   6.05   6.03  down
#  2021-10-26   6.23   6.05  down
#  ...           ...    ...   ...
#  2021-10-13   6.36   6.38    up
#  2021-10-14   6.35   6.36    up
#  2021-10-15   6.18   6.35    up
#  2021-10-18   5.99   6.18    up
#  2022-08-19   3.33   5.99    up
#
#  [1258 rows x 3 columns],
#  'ACOR':              Close  lag_1 label
#  Date
#  2021-10-20  4.4900   4.61    up
#  2021-10-21  4.3600   4.49    up
#  2021-10-22  4.1200   4.36    up
#  2021-10-25  4.0600   4.12    up
#  2021-10-26  4.0900   4.06  down
#  ...            ...    ...   ...
#  2021-10-13  4.6300   4.56  down
#  2021-10-14  4.6600   4.63  down
#  2021-10-15  4.7100   4.66  down
#  2021-10-18  4.6500   4.71    up
#  2022-08-19  0.4649   4.65    up
#
#  [1258 rows x 3 columns],
#  'ACRS':                 Close      lag_1 label
#  Date
#  2021-10-20  16.110001  16.090000  down
#  2021-10-21  16.090000  16.110001    up
#  2021-10-22  16.350000  16.090000  down
#  2021-10-25  16.190001  16.350000    up
#  2021-10-26  15.960000  16.190001    up
#  ...               ...        ...   ...
#  2021-10-13  17.180000  17.570000    up
#  2021-10-14  17.250000  17.180000  down
#  2021-10-15  16.809999  17.250000    up
#  2021-10-18  16.030001  16.809999    up
#  2022-08-19  16.379999  16.030001  down
#
#  [1258 rows x 3 columns],
#  'ACST':             Close  lag_1 label
#  Date
#  2021-10-20  1.800   1.73  down
#  2021-10-21  1.730   1.80    up
#  2021-10-22  1.680   1.73    up
#  2021-10-25  1.690   1.68  down
#  2021-10-26  1.690   1.69  down
#  ...           ...    ...   ...
#  2021-10-13  1.760   1.79    up
#  2021-10-14  1.740   1.76    up
#  2021-10-15  1.740   1.74  down
#  2021-10-18  1.710   1.74    up
#  2022-08-19  0.905   1.71    up
#
#  [1258 rows x 3 columns],
#  'ADAP':             Close  lag_1 label
#  Date
#  2021-10-20  5.200  5.270    up
#  2021-10-21  5.270  5.200  down
#  2021-10-22  5.210  5.270    up
#  2021-10-25  4.980  5.210    up
#  2021-10-26  5.030  4.980  down
#  ...           ...    ...   ...
#  2021-10-13  5.440  5.350  down
#  2021-10-14  5.450  5.440  down
#  2021-10-15  5.330  5.450    up
#  2021-10-18  5.225  5.330    up
#  2022-08-19  2.130  5.225    up
#
#  [1258 rows x 3 columns],
#  'ADIL':              Close  lag_1 label
#  Date
#  2021-10-20  4.1800   3.75  down
#  2021-10-21  3.8500   4.18    up
#  2021-10-22  3.4800   3.85    up
#  2021-10-25  3.3400   3.48    up
#  2021-10-26  3.3000   3.34    up
#  ...            ...    ...   ...
#  2021-10-13  4.1000   3.74  down
#  2021-10-14  3.9900   4.10    up
#  2021-10-15  3.8800   3.99    up
#  2021-10-18  3.7900   3.88    up
#  2022-08-19  0.5842   3.79    up
#
#  [1023 rows x 3 columns],
#  'ADMA':             Close  lag_1 label
#  Date
#  2021-10-20   1.11   1.11  down
#  2021-10-21   1.21   1.11  down
#  2021-10-22   1.28   1.21  down
#  2021-10-25   1.23   1.28    up
#  2021-10-26   1.35   1.23  down
#  ...           ...    ...   ...
#  2021-10-13   1.14   1.12  down
#  2021-10-14   1.11   1.14    up
#  2021-10-15   1.10   1.11    up
#  2021-10-18   1.10   1.10  down
#  2022-08-19   2.61   1.10  down
#
#  [1258 rows x 3 columns],
#  'ADVM':             Close  lag_1 label
#  Date
#  2021-10-20  2.010   2.04    up
#  2021-10-21  2.000   2.01    up
#  2021-10-22  1.950   2.00    up
#  2021-10-25  1.950   1.95  down
#  2021-10-26  1.940   1.95    up
#  ...           ...    ...   ...
#  2021-10-13  2.150   2.14  down
#  2021-10-14  2.140   2.15    up
#  2021-10-15  2.060   2.14    up
#  2021-10-18  2.020   2.06    up
#  2022-08-19  1.305   2.02    up
#
#  [1258 rows x 3 columns],
#  'ADXS':                 Close      lag_1 label
#  Date
#  2021-10-20  41.183998  40.647999  down
#  2021-10-21  40.287998  41.183998    up
#  2021-10-22  37.456001  40.287998    up
#  2021-10-25  38.888000  37.456001  down
#  2021-10-26  39.535999  38.888000  down
#  ...               ...        ...   ...
#  2021-10-12  40.816002  38.504002  down
#  2021-10-13  41.880001  40.816002  down
#  2021-10-14  38.880001  41.880001    up
#  2021-10-15  37.759998  38.880001    up
#  2021-10-18  38.959999  37.759998  down
#
#  [1257 rows x 3 columns],
#  'AEZS':             Close  lag_1 label
#  Date
#  2021-10-20  15.50  15.50  down
#  2021-10-21  15.25  15.50    up
#  2021-10-22  14.75  15.25    up
#  2021-10-25  14.75  14.75  down
#  2021-10-26  15.25  14.75  down
#  ...           ...    ...   ...
#  2021-10-13  15.50  15.25  down
#  2021-10-14  15.50  15.50  down
#  2021-10-15  15.00  15.50    up
#  2021-10-18  15.25  15.00  down
#  2022-08-19   5.42  15.25    up
#
#  [1258 rows x 3 columns],
#  'AFMD':             Close  lag_1 label
#  Date
#  2021-10-20   6.07   5.97  down
#  2021-10-21   6.15   6.07  down
#  2021-10-22   5.99   6.15    up
#  2021-10-25   6.19   5.99  down
#  2021-10-26   6.69   6.19  down
#  ...           ...    ...   ...
#  2021-10-13   5.85   5.89    up
#  2021-10-14   5.94   5.85  down
#  2021-10-15   5.91   5.94    up
#  2021-10-18   5.83   5.91    up
#  2022-08-19   3.04   5.83    up
#
#  [1258 rows x 3 columns],
#  'AGE':             Close  lag_1 label
#  Date
#  2021-10-20  0.915  0.910  down
#  2021-10-21  0.905  0.915    up
#  2021-10-22  0.903  0.905    up
#  2021-10-25  0.905  0.903  down
#  2021-10-26  0.880  0.905    up
#  ...           ...    ...   ...
#  2021-10-13  0.920  0.910  down
#  2021-10-14  0.922  0.920  down
#  2021-10-15  0.920  0.922    up
#  2021-10-18  0.920  0.920  down
#  2022-08-19  0.670  0.920    up
#
#  [936 rows x 3 columns],
#  'AGEN':              Close  lag_1 label
#  Date
#  2021-10-20  5.0000   5.05    up
#  2021-10-21  5.1300   5.00  down
#  2021-10-22  4.0100   5.13    up
#  2021-10-25  3.7900   4.01    up
#  2021-10-26  3.7900   3.79  down
#  ...            ...    ...   ...
#  2021-10-13  5.4000   5.64    up
#  2021-10-14  5.5000   5.40  down
#  2021-10-15  5.3100   5.50    up
#  2021-10-18  5.0900   5.31    up
#  2022-08-19  2.7801   5.09    up
#
#  [1258 rows x 3 columns],
#  'AGIO':                 Close      lag_1 label
#  Date
#  2021-10-20  47.580002  45.820000  down
#  2021-10-21  47.990002  47.580002  down
#  2021-10-22  48.549999  47.990002  down
#  2021-10-25  48.889999  48.549999  down
#  2021-10-26  48.020000  48.889999    up
#  ...               ...        ...   ...
#  2021-10-13  45.529999  45.540001    up
#  2021-10-14  46.730000  45.529999  down
#  2021-10-15  46.279999  46.730000    up
#  2021-10-18  44.279999  46.279999    up
#  2022-08-19  25.490000  44.279999    up
#
#  [1258 rows x 3 columns],
#  'AGLE':             Close  lag_1 label
#  Date
#  2021-10-20  7.560   7.53  down
#  2021-10-21  7.290   7.56    up
#  2021-10-22  7.300   7.29  down
#  2021-10-25  7.670   7.30  down
#  2021-10-26  7.590   7.67    up
#  ...           ...    ...   ...
#  2021-10-13  7.930   8.04    up
#  2021-10-14  8.420   7.93  down
#  2021-10-15  8.180   8.42    up
#  2021-10-18  7.640   8.18    up
#  2022-08-19  0.714   7.64    up
#
#  [1258 rows x 3 columns],
#  'AGTC':              Close  lag_1 label
#  Date
#  2021-10-20  2.6900   2.68  down
#  2021-10-21  2.6600   2.69    up
#  2021-10-22  2.5800   2.66    up
#  2021-10-25  2.5700   2.58    up
#  2021-10-26  2.6900   2.57  down
#  ...            ...    ...   ...
#  2021-10-13  2.7400   2.74  down
#  2021-10-14  2.7300   2.74    up
#  2021-10-15  2.6600   2.73    up
#  2021-10-18  2.6300   2.66    up
#  2022-08-19  0.4026   2.63    up
#
#  [1258 rows x 3 columns],
#  'AKBA':              Close  lag_1 label
#  Date
#  2021-10-20  2.8700   2.85  down
#  2021-10-21  2.9000   2.87  down
#  2021-10-22  2.9100   2.90  down
#  2021-10-25  2.8600   2.91    up
#  2021-10-26  2.8300   2.86    up
#  ...            ...    ...   ...
#  2021-10-13  2.9400   2.95    up
#  2021-10-14  2.9200   2.94    up
#  2021-10-15  2.8500   2.92    up
#  2021-10-18  2.8100   2.85    up
#  2022-08-19  0.3852   2.81    up
#
#  [1258 rows x 3 columns],
#  'AKTX':             Close  lag_1 label
#  Date
#  2021-10-20  1.730  1.698  down
#  2021-10-21  1.690  1.730    up
#  2021-10-22  1.690  1.690  down
#  2021-10-25  1.740  1.690  down
#  2021-10-26  1.700  1.740    up
#  ...           ...    ...   ...
#  2021-10-13  1.690  1.600  down
#  2021-10-14  1.640  1.690    up
#  2021-10-15  1.650  1.640  down
#  2021-10-18  1.678  1.650  down
#  2022-08-19  1.350  1.678    up
#
#  [1258 rows x 3 columns],
#  'ALBO':                 Close      lag_1 label
#  Date
#  2021-10-20  29.530001  29.799999    up
#  2021-10-21  29.490000  29.530001    up
#  2021-10-22  29.219999  29.490000    up
#  2021-10-25  29.010000  29.219999    up
#  2021-10-26  28.690001  29.010000    up
#  ...               ...        ...   ...
#  2021-10-13  30.209999  30.410000    up
#  2021-10-14  31.070000  30.209999  down
#  2021-10-15  31.240000  31.070000  down
#  2021-10-18  29.580000  31.240000    up
#  2022-08-19  17.000000  29.580000    up
#
#  [1258 rows x 3 columns],
#  'ALDX':             Close  lag_1 label
#  Date
#  2021-10-20   8.14   8.41    up
#  2021-10-21   8.14   8.14  down
#  2021-10-22   8.03   8.14    up
#  2021-10-25   8.09   8.03  down
#  2021-10-26   8.01   8.09    up
#  ...           ...    ...   ...
#  2021-10-13   8.62   8.60  down
#  2021-10-14   8.71   8.62  down
#  2021-10-15   8.34   8.71    up
#  2021-10-18   8.38   8.34  down
#  2022-08-19   7.12   8.38    up
#
#  [1258 rows x 3 columns],
#  'ALKS':                 Close      lag_1 label
#  Date
#  2021-10-20  30.870001  31.010000    up
#  2021-10-21  30.660000  30.870001    up
#  2021-10-22  30.850000  30.660000  down
#  2021-10-25  31.799999  30.850000  down
#  2021-10-26  31.510000  31.799999    up
#  ...               ...        ...   ...
#  2021-10-13  31.440001  31.580000    up
#  2021-10-14  31.850000  31.440001  down
#  2021-10-15  31.670000  31.850000    up
#  2021-10-18  30.299999  31.670000    up
#  2022-08-19  25.315001  30.299999    up
#
#  [1258 rows x 3 columns],
#  'ALLK':                  Close       lag_1 label
#  Date
#  2021-10-20  102.269997  104.570000    up
#  2021-10-21  103.620003  102.269997  down
#  2021-10-22  108.160004  103.620003  down
#  2021-10-25  108.970001  108.160004  down
#  2021-10-26  111.889999  108.970001  down
#  ...                ...         ...   ...
#  2021-10-13  105.360001  105.440002    up
#  2021-10-14  107.120003  105.360001  down
#  2021-10-15  107.480003  107.120003  down
#  2021-10-18  104.040001  107.480003    up
#  2022-08-19    3.628100  104.040001    up
#
#  [1029 rows x 3 columns],
#  'ALLO':             Close  lag_1 label
#  Date
#  2021-10-20  15.82  15.74  down
#  2021-10-21  15.94  15.82  down
#  2021-10-22  15.82  15.94    up
#  2021-10-25  15.65  15.82    up
#  2021-10-26  16.02  15.65  down
#  ...           ...    ...   ...
#  2021-10-13  15.94  13.43  down
#  2021-10-14  17.17  15.94  down
#  2021-10-15  16.48  17.17    up
#  2021-10-18  15.73  16.48    up
#  2022-08-19  14.90  15.73    up
#
#  [970 rows x 3 columns],
#  'ALNA':              Close  lag_1 label
#  Date
#  2021-10-20  0.9150  0.890  down
#  2021-10-21  0.9040  0.915    up
#  2021-10-22  0.8760  0.904    up
#  2021-10-25  0.8500  0.876    up
#  2021-10-26  0.8500  0.850  down
#  ...            ...    ...   ...
#  2021-10-13  0.8870  0.885  down
#  2021-10-14  0.8900  0.887  down
#  2021-10-15  0.9030  0.890  down
#  2021-10-18  0.8870  0.903    up
#  2022-08-19  0.1116  0.887    up
#
#  [1206 rows x 3 columns],
#  'ALNY':                  Close       lag_1 label
#  Date
#  2021-10-20  203.820007  206.589996    up
#  2021-10-21  204.330002  203.820007  down
#  2021-10-22  198.610001  204.330002    up
#  2021-10-25  199.669998  198.610001  down
#  2021-10-26  197.710007  199.669998    up
#  ...                ...         ...   ...
#  2021-10-13  203.889999  203.440002  down
#  2021-10-14  209.289993  203.889999  down
#  2021-10-15  208.559998  209.289993    up
#  2021-10-18  203.899994  208.559998    up
#  2022-08-19  217.449997  203.899994  down
#
#  [1258 rows x 3 columns],
#  'ALPN':             Close  lag_1 label
#  Date
#  2021-10-20  10.68  10.62  down
#  2021-10-21  10.64  10.68    up
#  2021-10-22  10.55  10.64    up
#  2021-10-25  10.94  10.55  down
#  2021-10-26  10.78  10.94    up
#  ...           ...    ...   ...
#  2021-10-13  11.84  11.46  down
#  2021-10-14  11.49  11.84    up
#  2021-10-15  11.38  11.49    up
#  2021-10-18  10.99  11.38    up
#  2022-08-19   8.19  10.99    up
#
#  [1258 rows x 3 columns],
#  'ALRN':              Close  lag_1 label
#  Date
#  2021-10-20  0.9840  0.971  down
#  2021-10-21  1.0100  0.984  down
#  2021-10-22  0.9620  1.010    up
#  2021-10-25  0.9230  0.962    up
#  2021-10-26  0.9080  0.923    up
#  ...            ...    ...   ...
#  2021-10-13  0.9900  0.950  down
#  2021-10-14  1.0300  0.990  down
#  2021-10-15  1.0100  1.030    up
#  2021-10-18  0.9770  1.010    up
#  2022-08-19  0.2123  0.977    up
#
#  [1258 rows x 3 columns],
#  'ALT':             Close  lag_1 label
#  Date
#  2021-10-20  11.93  12.39    up
#  2021-10-21  11.80  11.93    up
#  2021-10-22  11.52  11.80    up
#  2021-10-25  11.39  11.52    up
#  2021-10-26  11.28  11.39    up
#  ...           ...    ...   ...
#  2021-10-13  12.43  12.41  down
#  2021-10-14  12.48  12.43  down
#  2021-10-15  12.01  12.48    up
#  2021-10-18  12.20  12.01  down
#  2022-08-19  17.41  12.20  down
#
#  [1258 rows x 3 columns],
#  'AMGN':                  Close       lag_1 label
#  Date
#  2021-10-20  209.660004  206.779999  down
#  2021-10-21  208.990005  209.660004    up
#  2021-10-22  209.240005  208.990005  down
#  2021-10-25  207.630005  209.240005    up
#  2021-10-26  208.679993  207.630005  down
#  ...                ...         ...   ...
#  2021-10-13  203.610001  201.889999  down
#  2021-10-14  206.779999  203.610001  down
#  2021-10-15  207.839996  206.779999  down
#  2021-10-18  203.130005  207.839996    up
#  2022-08-19  250.220001  203.130005  down
#
#  [1258 rows x 3 columns],
#  'AMPE':              Close  lag_1 label
#  Date
#  2021-10-20  1.7100   1.63  down
#  2021-10-21  1.6800   1.71    up
#  2021-10-22  1.6200   1.68    up
#  2021-10-25  1.5800   1.62    up
#  2021-10-26  1.5200   1.58    up
#  ...            ...    ...   ...
#  2021-10-13  1.6700   1.69    up
#  2021-10-14  1.7000   1.67  down
#  2021-10-15  1.7000   1.70  down
#  2021-10-18  1.6300   1.70    up
#  2022-08-19  0.0927   1.63    up
#
#  [1258 rows x 3 columns],
#  'AMRN':             Close  lag_1 label
#  Date
#  2021-10-20  5.030   5.05    up
#  2021-10-21  5.010   5.03    up
#  2021-10-22  5.000   5.01    up
#  2021-10-25  4.760   5.00    up
#  2021-10-26  4.650   4.76    up
#  ...           ...    ...   ...
#  2021-10-13  5.170   5.18    up
#  2021-10-14  5.170   5.17  down
#  2021-10-15  5.160   5.17    up
#  2021-10-18  5.040   5.16    up
#  2022-08-19  1.575   5.04    up
#
#  [1258 rows x 3 columns],
#  'ANAB':                 Close      lag_1 label
#  Date
#  2021-10-20  28.510000  27.440001  down
#  2021-10-21  28.530001  28.510000  down
#  2021-10-22  28.549999  28.530001  down
#  2021-10-25  29.000000  28.549999  down
#  2021-10-26  30.980000  29.000000  down
#  ...               ...        ...   ...
#  2021-10-13  27.600000  28.820000    up
#  2021-10-14  28.309999  27.600000  down
#  2021-10-15  28.670000  28.309999  down
#  2021-10-18  28.240000  28.670000    up
#  2022-08-19  24.820000  28.240000    up
#
#  [1258 rows x 3 columns],
#  'ANIK':                 Close      lag_1 label
#  Date
#  2021-10-20  41.930000  41.630001  down
#  2021-10-21  41.580002  41.930000    up
#  2021-10-22  42.049999  41.580002  down
#  2021-10-25  42.630001  42.049999  down
#  2021-10-26  42.110001  42.630001    up
#  ...               ...        ...   ...
#  2021-10-13  41.169998  41.299999    up
#  2021-10-14  41.980000  41.169998  down
#  2021-10-15  41.660000  41.980000    up
#  2021-10-18  41.009998  41.660000    up
#  2022-08-19  23.080799  41.009998    up
#
#  [1258 rows x 3 columns],
#  'ANIP':                 Close      lag_1 label
#  Date
#  2021-10-20  37.860001  38.029999    up
#  2021-10-21  37.820000  37.860001    up
#  2021-10-22  36.860001  37.820000    up
#  2021-10-25  38.080002  36.860001  down
#  2021-10-26  38.540001  38.080002  down
#  ...               ...        ...   ...
#  2021-10-13  38.160000  36.759998  down
#  2021-10-14  37.720001  38.160000    up
#  2021-10-15  38.540001  37.720001  down
#  2021-10-18  37.770000  38.540001    up
#  2022-08-19  35.380001  37.770000    up
#
#  [1258 rows x 3 columns],
#  'APLS':                 Close      lag_1 label
#  Date
#  2021-10-20  32.020000  33.180000    up
#  2021-10-21  32.000000  32.020000    up
#  2021-10-22  31.370001  32.000000    up
#  2021-10-25  32.090000  31.370001  down
#  2021-10-26  31.760000  32.090000    up
#  ...               ...        ...   ...
#  2021-10-13  33.950001  33.639999  down
#  2021-10-14  35.419998  33.950001  down
#  2021-10-15  34.630001  35.419998    up
#  2021-10-18  33.570000  34.630001    up
#  2022-08-19  65.029999  33.570000  down
#
#  [1201 rows x 3 columns],
#  'APM':             Close  lag_1 label
#  Date
#  2021-10-20   2.52  2.500  down
#  2021-10-21   2.50  2.520    up
#  2021-10-22   2.48  2.500    up
#  2021-10-25   2.46  2.480    up
#  2021-10-26   2.50  2.460  down
#  ...           ...    ...   ...
#  2021-10-13   2.63  2.575  down
#  2021-10-14   2.60  2.630    up
#  2021-10-15   2.59  2.600    up
#  2021-10-18   2.64  2.590  down
#  2022-08-19   1.59  2.640    up
#
#  [924 rows x 3 columns],
#  'APTO':              Close  lag_1 label
#  Date
#  2021-10-20  2.1200   2.18    up
#  2021-10-21  2.2300   2.12  down
#  2021-10-22  2.1900   2.23    up
#  2021-10-25  2.1400   2.19    up
#  2021-10-26  2.0900   2.14    up
#  ...            ...    ...   ...
#  2021-10-13  2.2800   2.19  down
#  2021-10-14  2.3100   2.28  down
#  2021-10-15  2.3000   2.31    up
#  2021-10-18  2.2600   2.30    up
#  2022-08-19  0.8405   2.26    up
#
#  [1258 rows x 3 columns],
#  'APTX':              Close  lag_1 label
#  Date
#  2021-10-20  2.2400   2.26    up
#  2021-10-21  2.2400   2.24  down
#  2021-10-22  2.2200   2.24    up
#  2021-10-25  2.2500   2.22  down
#  2021-10-26  2.2200   2.25    up
#  ...            ...    ...   ...
#  2021-10-13  2.3100   2.25  down
#  2021-10-14  2.3000   2.31    up
#  2021-10-15  2.2500   2.30    up
#  2021-10-18  2.2200   2.25    up
#  2022-08-19  0.3485   2.22    up
#
#  [1048 rows x 3 columns],
#  'APVO':               Close  lag_1 label
#  Date
#  2021-10-20  14.9100  14.44  down
#  2021-10-21  14.9900  14.91  down
#  2021-10-22  14.2500  14.99    up
#  2021-10-25  14.5200  14.25  down
#  2021-10-26  14.7000  14.52  down
#  ...             ...    ...   ...
#  2021-10-13  15.7100  14.49  down
#  2021-10-14  15.0000  15.71    up
#  2021-10-15  14.9900  15.00    up
#  2021-10-18  14.6400  14.99    up
#  2022-08-19   3.8656  14.64    up
#
#  [1258 rows x 3 columns],
#  'AQB':             Close  lag_1 label
#  Date
#  2021-10-20  4.060   4.14    up
#  2021-10-21  4.030   4.06    up
#  2021-10-22  3.930   4.03    up
#  2021-10-25  4.040   3.93  down
#  2021-10-26  4.030   4.04    up
#  ...           ...    ...   ...
#  2021-10-13  4.080   3.92  down
#  2021-10-14  4.030   4.08    up
#  2021-10-15  3.910   4.03    up
#  2021-10-18  3.920   3.91  down
#  2022-08-19  1.325   3.92    up
#
#  [1258 rows x 3 columns],
#  'AQST':             Close  lag_1 label
#  Date
#  2021-10-20  4.390   4.24  down
#  2021-10-21  4.470   4.39  down
#  2021-10-22  4.330   4.47    up
#  2021-10-25  4.670   4.33  down
#  2021-10-26  4.950   4.67  down
#  ...           ...    ...   ...
#  2021-10-13  3.940   3.77  down
#  2021-10-14  3.840   3.94    up
#  2021-10-15  3.870   3.84  down
#  2021-10-18  4.070   3.87  down
#  2022-08-19  1.445   4.07    up
#
#  [1025 rows x 3 columns],
#  'ARAV':              Close  lag_1 label
#  Date
#  2021-10-20  3.7400  3.770    up
#  2021-10-21  3.7150  3.740    up
#  2021-10-22  3.6700  3.715    up
#  2021-10-25  3.6100  3.670    up
#  2021-10-26  3.6600  3.610  down
#  ...            ...    ...   ...
#  2021-10-13  3.7900  3.760  down
#  2021-10-14  3.8300  3.790  down
#  2021-10-15  3.6800  3.830    up
#  2021-10-18  3.7600  3.680  down
#  2022-08-19  0.8201  3.760    up
#
#  [1258 rows x 3 columns],
#  'ARCT':                 Close      lag_1 label
#  Date
#  2021-10-20  43.810001  45.169998    up
#  2021-10-21  44.570000  43.810001  down
#  2021-10-22  44.509998  44.570000    up
#  2021-10-25  45.169998  44.509998  down
#  2021-10-26  45.119999  45.169998    up
#  ...               ...        ...   ...
#  2021-10-13  45.209999  44.250000  down
#  2021-10-14  46.980000  45.209999  down
#  2021-10-15  45.560001  46.980000    up
#  2021-10-18  45.689999  45.560001  down
#  2022-08-19  17.219999  45.689999    up
#
#  [1258 rows x 3 columns],
#  'ARDS':             Close  lag_1 label
#  Date
#  2021-10-20   3.39   3.54    up
#  2021-10-21   3.35   3.39    up
#  2021-10-22   3.29   3.35    up
#  2021-10-25   3.35   3.29  down
#  2021-10-26   3.42   3.35  down
#  ...           ...    ...   ...
#  2021-10-13   3.61   3.64    up
#  2021-10-14   3.65   3.61  down
#  2021-10-15   3.52   3.65    up
#  2021-10-18   3.49   3.52    up
#  2022-08-19   1.80   3.49    up
#
#  [1011 rows x 3 columns],
#  'ARDX':             Close  lag_1 label
#  Date
#  2021-10-20   1.10   1.05  down
#  2021-10-21   1.19   1.10  down
#  2021-10-22   1.14   1.19    up
#  2021-10-25   1.16   1.14  down
#  2021-10-26   1.15   1.16    up
#  ...           ...    ...   ...
#  2021-10-13   1.09   1.32    up
#  2021-10-14   1.17   1.09  down
#  2021-10-15   1.08   1.17    up
#  2021-10-18   1.02   1.08    up
#  2022-08-19   1.04   1.02  down
#
#  [1258 rows x 3 columns],
#  'ARGX':                  Close       lag_1 label
#  Date
#  2021-10-20  296.019989  295.579987  down
#  2021-10-21  294.170013  296.019989    up
#  2021-10-22  293.160004  294.170013    up
#  2021-10-25  286.540009  293.160004    up
#  2021-10-26  281.850006  286.540009    up
#  ...                ...         ...   ...
#  2021-10-13  295.500000  294.260010  down
#  2021-10-14  295.149994  295.500000    up
#  2021-10-15  293.739990  295.149994    up
#  2021-10-18  291.929993  293.739990    up
#  2022-08-19  383.279999  291.929993  down
#
#  [1258 rows x 3 columns],
#  'ARRY':                 Close      lag_1 label
#  Date
#  2021-10-20  18.660000  20.410000    up
#  2021-10-21  19.049999  18.660000  down
#  2021-10-22  17.920000  19.049999    up
#  2021-10-25  18.200001  17.920000  down
#  2021-10-26  17.840000  18.200001    up
#  ...               ...        ...   ...
#  2021-10-13  19.950001  19.910000  down
#  2021-10-14  20.000000  19.950001  down
#  2021-10-15  18.870001  20.000000    up
#  2021-10-18  19.410000  18.870001  down
#  2022-08-19  20.530600  19.410000  down
#
#  [464 rows x 3 columns],
#  'ARVN':                 Close      lag_1 label
#  Date
#  2021-10-20  85.089996  82.779999  down
#  2021-10-21  88.089996  85.089996  down
#  2021-10-22  84.919998  88.089996    up
#  2021-10-25  84.739998  84.919998    up
#  2021-10-26  85.250000  84.739998  down
#  ...               ...        ...   ...
#  2021-10-13  84.860001  83.809998  down
#  2021-10-14  87.769997  84.860001  down
#  2021-10-15  85.099998  87.769997    up
#  2021-10-18  82.269997  85.099998    up
#  2022-08-19  44.889999  82.269997    up
#
#  [980 rows x 3 columns],
#  'ARWR':                 Close      lag_1 label
#  Date
#  2021-10-20  66.750000  67.070000    up
#  2021-10-21  66.889999  66.750000  down
#  2021-10-22  66.029999  66.889999    up
#  2021-10-25  65.849998  66.029999    up
#  2021-10-26  66.089996  65.849998  down
#  ...               ...        ...   ...
#  2021-10-13  63.369999  63.270000  down
#  2021-10-14  66.830002  63.369999  down
#  2021-10-15  66.160004  66.830002    up
#  2021-10-18  66.139999  66.160004    up
#  2022-08-19  43.180000  66.139999    up
#
#  [1258 rows x 3 columns],
#  'ASLN':             Close  lag_1 label
#  Date
#  2021-10-20   1.56   1.61    up
#  2021-10-21   1.59   1.56  down
#  2021-10-22   1.47   1.59    up
#  2021-10-25   1.39   1.47    up
#  2021-10-26   1.52   1.39  down
#  ...           ...    ...   ...
#  2021-10-13   1.66   1.59  down
#  2021-10-14   1.61   1.66    up
#  2021-10-15   1.56   1.61    up
#  2021-10-18   1.59   1.56  down
#  2022-08-19   0.90   1.59    up
#
#  [1081 rows x 3 columns],
#  'ASMB':             Close  lag_1 label
#  Date
#  2021-10-20  3.250   3.25  down
#  2021-10-21  3.230   3.25    up
#  2021-10-22  3.130   3.23    up
#  2021-10-25  3.090   3.13    up
#  2021-10-26  3.080   3.09    up
#  ...           ...    ...   ...
#  2021-10-13  3.320   3.33    up
#  2021-10-14  3.270   3.32    up
#  2021-10-15  3.260   3.27    up
#  2021-10-18  3.210   3.26    up
#  2022-08-19  2.045   3.21    up
#
#  [1258 rows x 3 columns],
#  'ASND':                  Close       lag_1 label
#  Date
#  2021-10-20  145.000000  153.490005    up
#  2021-10-21  145.619995  145.000000  down
#  2021-10-22  144.610001  145.619995    up
#  2021-10-25  140.740005  144.610001    up
#  2021-10-26  139.740005  140.740005    up
#  ...                ...         ...   ...
#  2021-10-13  164.000000  168.740005    up
#  2021-10-14  160.000000  164.000000    up
#  2021-10-15  159.990005  160.000000    up
#  2021-10-18  155.315002  159.990005    up
#  2022-08-19   93.629997  155.315002    up
#
#  [1258 rows x 3 columns],
#  'ASNS':             Close  lag_1 label
#  Date
#  2022-05-16   1.95   2.40    up
#  2022-05-17   1.95   1.95  down
#  2022-05-18   1.84   1.95    up
#  2022-05-19   1.59   1.84    up
#  2022-05-20   1.51   1.59    up
#  ...           ...    ...   ...
#  2022-08-15   1.37   1.33  down
#  2022-08-16   1.39   1.37  down
#  2022-08-17   1.32   1.39    up
#  2022-08-18   1.37   1.32  down
#  2022-08-19   1.37   1.37  down
#
#  [67 rows x 3 columns],
#  'ATHX':              Close  lag_1 label
#  Date
#  2021-10-20  1.3200   1.31  down
#  2021-10-21  1.2600   1.32    up
#  2021-10-22  1.2400   1.26    up
#  2021-10-25  1.2300   1.24    up
#  2021-10-26  1.1800   1.23    up
#  ...            ...    ...   ...
#  2021-10-13  1.3100   1.33    up
#  2021-10-14  1.2900   1.31    up
#  2021-10-15  1.2900   1.29  down
#  2021-10-18  1.2500   1.29    up
#  2022-08-19  0.1983   1.25    up
#
#  [1258 rows x 3 columns],
#  'ATNM':             Close  lag_1 label
#  Date
#  2021-10-20   7.97   7.85  down
#  2021-10-21   7.87   7.97    up
#  2021-10-22   8.25   7.87  down
#  2021-10-25   7.74   8.25    up
#  2021-10-26   8.00   7.74  down
#  ...           ...    ...   ...
#  2021-10-13   8.49   8.07  down
#  2021-10-14   8.20   8.49    up
#  2021-10-15   8.04   8.20    up
#  2021-10-18   7.80   8.04    up
#  2022-08-19   5.83   7.80    up
#
#  [1258 rows x 3 columns],
#  'ATNX':              Close  lag_1 label
#  Date
#  2021-10-20  2.6900   2.74    up
#  2021-10-21  2.6300   2.69    up
#  2021-10-22  2.5200   2.63    up
#  2021-10-25  2.5900   2.52  down
#  2021-10-26  2.5200   2.59    up
#  ...            ...    ...   ...
#  2021-10-13  2.7100   2.68  down
#  2021-10-14  2.9000   2.71  down
#  2021-10-15  2.7700   2.90    up
#  2021-10-18  2.6300   2.77    up
#  2022-08-19  0.4777   2.63    up
#
#  [1258 rows x 3 columns],
#  'ATRA':                 Close      lag_1 label
#  Date
#  2021-10-20  15.710000  15.130000  down
#  2021-10-21  15.810000  15.710000  down
#  2021-10-22  16.030001  15.810000  down
#  2021-10-25  15.180000  16.030001    up
#  2021-10-26  15.200000  15.180000  down
#  ...               ...        ...   ...
#  2021-10-13  15.660000  17.980000    up
#  2021-10-14  15.760000  15.660000  down
#  2021-10-15  15.120000  15.760000    up
#  2021-10-18  14.700000  15.120000    up
#  2022-08-19   4.500000  14.700000    up
#
#  [1258 rows x 3 columns],
#  'AUPH':                 Close      lag_1 label
#  Date
#  2021-10-20  20.650000  19.930000  down
#  2021-10-21  22.090000  20.650000  down
#  2021-10-22  28.000000  22.090000  down
#  2021-10-25  29.840000  28.000000  down
#  2021-10-26  30.350000  29.840000  down
#  ...               ...        ...   ...
#  2021-10-13  21.250000  20.690001  down
#  2021-10-14  21.040001  21.250000    up
#  2021-10-15  20.570000  21.040001    up
#  2021-10-18  19.700001  20.570000    up
#  2022-08-19   8.050000  19.700001    up
#
#  [1258 rows x 3 columns],
#  'AUTL':             Close  lag_1 label
#  Date
#  2021-10-20   5.90   5.97    up
#  2021-10-21   5.79   5.90    up
#  2021-10-22   5.58   5.79    up
#  2021-10-25   5.61   5.58  down
#  2021-10-26   5.61   5.61  down
#  ...           ...    ...   ...
#  2021-10-13   6.18   6.00  down
#  2021-10-14   6.20   6.18  down
#  2021-10-15   6.14   6.20    up
#  2021-10-18   5.92   6.14    up
#  2022-08-19   3.49   5.92    up
#
#  [1047 rows x 3 columns],
#  'AVDL':             Close  lag_1 label
#  Date
#  2021-10-20   8.44   8.46    up
#  2021-10-21   8.22   8.44    up
#  2021-10-22   8.14   8.22    up
#  2021-10-25   8.16   8.14  down
#  2021-10-26   8.52   8.16  down
#  ...           ...    ...   ...
#  2021-10-13  10.17  10.09  down
#  2021-10-14   9.34  10.17    up
#  2021-10-15   9.99   9.34  down
#  2021-10-18   8.45   9.99    up
#  2022-08-19   6.67   8.45    up
#
#  [1258 rows x 3 columns],
#  'AVEO':             Close  lag_1 label
#  Date
#  2021-10-20   6.62   6.51  down
#  2021-10-21   6.60   6.62    up
#  2021-10-22   6.66   6.60  down
#  2021-10-25   6.62   6.66    up
#  2021-10-26   6.72   6.62  down
#  ...           ...    ...   ...
#  2021-10-13   6.56   6.55  down
#  2021-10-14   6.58   6.56  down
#  2021-10-15   6.45   6.58    up
#  2021-10-18   6.30   6.45    up
#  2022-08-19   7.70   6.30  down
#
#  [1258 rows x 3 columns],
#  'AVRO':             Close  lag_1 label
#  Date
#  2021-10-20   5.58   5.67    up
#  2021-10-21   5.54   5.58    up
#  2021-10-22   5.52   5.54    up
#  2021-10-25   5.45   5.52    up
#  2021-10-26   5.51   5.45  down
#  ...           ...    ...   ...
#  2021-10-13   5.63   5.66    up
#  2021-10-14   5.86   5.63  down
#  2021-10-15   5.80   5.86    up
#  2021-10-18   5.57   5.80    up
#  2022-08-19   1.04   5.57    up
#
#  [1048 rows x 3 columns],
#  'AVXL':                 Close      lag_1 label
#  Date
#  2021-10-20  17.879999  18.000000    up
#  2021-10-21  17.980000  17.879999  down
#  2021-10-22  17.840000  17.980000    up
#  2021-10-25  17.860001  17.840000  down
#  2021-10-26  17.900000  17.860001  down
#  ...               ...        ...   ...
#  2021-10-13  17.670000  17.240000  down
#  2021-10-14  17.840000  17.670000  down
#  2021-10-15  17.520000  17.840000    up
#  2021-10-18  17.760000  17.520000  down
#  2022-08-19  10.130000  17.760000    up
#
#  [1258 rows x 3 columns],
#  'AXON':                  Close       lag_1 label
#  Date
#  2021-10-20  179.050003  185.270004    up
#  2021-10-21  184.600006  179.050003  down
#  2021-10-22  182.649994  184.600006    up
#  2021-10-25  179.800003  182.649994    up
#  2021-10-26  180.199997  179.800003  down
#  ...                ...         ...   ...
#  2021-10-13  176.619995  171.429993  down
#  2021-10-14  179.029999  176.619995  down
#  2021-10-15  177.940002  179.029999    up
#  2021-10-18  181.699997  177.940002  down
#  2022-08-19  130.550003  181.699997    up
#
#  [1258 rows x 3 columns],
#  'AXSM':                 Close      lag_1 label
#  Date
#  2021-10-20  41.910000  40.180000  down
#  2021-10-21  40.820000  41.910000    up
#  2021-10-22  40.099998  40.820000    up
#  2021-10-25  39.290001  40.099998    up
#  2021-10-26  39.689999  39.290001  down
#  ...               ...        ...   ...
#  2021-10-13  42.169998  37.790001  down
#  2021-10-14  40.619999  42.169998    up
#  2021-10-15  40.099998  40.619999    up
#  2021-10-18  41.119999  40.099998  down
#  2022-08-19  59.230000  41.119999  down
#
#  [1258 rows x 3 columns],
#  'AYTU':              Close  lag_1 label
#  Date
#  2021-10-20  2.6000   2.61    up
#  2021-10-21  2.5600   2.60    up
#  2021-10-22  2.4600   2.56    up
#  2021-10-25  2.4700   2.46  down
#  2021-10-26  2.3800   2.47    up
#  ...            ...    ...   ...
#  2021-10-13  2.6700   2.63  down
#  2021-10-14  2.6700   2.67  down
#  2021-10-15  2.6500   2.67    up
#  2021-10-18  2.5400   2.65    up
#  2022-08-19  0.2731   2.54    up
#
#  [1258 rows x 3 columns],
#  'BCLI':             Close  lag_1 label
#  Date
#  2021-10-20  3.130   3.14    up
#  2021-10-21  3.100   3.13    up
#  2021-10-22  3.080   3.10    up
#  2021-10-25  3.060   3.08    up
#  2021-10-26  2.970   3.06    up
#  ...           ...    ...   ...
#  2021-10-13  3.150   3.14  down
#  2021-10-14  3.140   3.15    up
#  2021-10-15  3.080   3.14    up
#  2021-10-18  3.100   3.08  down
#  2022-08-19  3.735   3.10  down
#
#  [1258 rows x 3 columns],
#  'BCRX':             Close  lag_1 label
#  Date
#  2021-10-20  14.33  15.04    up
#  2021-10-21  14.61  14.33  down
#  2021-10-22  14.70  14.61  down
#  2021-10-25  15.46  14.70  down
#  2021-10-26  15.38  15.46    up
#  ...           ...    ...   ...
#  2021-10-13  14.99  14.71  down
#  2021-10-14  15.45  14.99  down
#  2021-10-15  15.13  15.45    up
#  2021-10-18  14.92  15.13    up
#  2022-08-19  14.00  14.92    up
#
#  [1258 rows x 3 columns],
#  'BDSI':             Close  lag_1 label
#  Date
#  2021-10-20   4.14   4.13  down
#  2021-10-21   4.13   4.14    up
#  2021-10-22   4.14   4.13  down
#  2021-10-25   4.05   4.14    up
#  2021-10-26   4.02   4.05    up
#  ...           ...    ...   ...
#  2021-10-12   4.04   3.99  down
#  2021-10-13   4.02   4.04    up
#  2021-10-14   3.94   4.02    up
#  2021-10-15   4.01   3.94  down
#  2021-10-18   4.08   4.01  down
#
#  [1161 rows x 3 columns],
#  'BGNE':                  Close       lag_1 label
#  Date
#  2021-10-20  372.600006  376.000000    up
#  2021-10-21  375.279999  372.600006  down
#  2021-10-22  378.880005  375.279999  down
#  2021-10-25  387.450012  378.880005  down
#  2021-10-26  383.640015  387.450012    up
#  ...                ...         ...   ...
#  2021-10-13  356.410004  357.920013    up
#  2021-10-14  355.459991  356.410004    up
#  2021-10-15  358.429993  355.459991  down
#  2021-10-18  360.809998  358.429993  down
#  2022-08-19  173.649994  360.809998    up
#
#  [1258 rows x 3 columns],
#  'BHVN':                  Close       lag_1 label
#  Date
#  2021-10-20  131.580002  128.100006  down
#  2021-10-21  136.880005  131.580002  down
#  2021-10-22  139.899994  136.880005  down
#  2021-10-25  138.839996  139.899994    up
#  2021-10-26  141.419998  138.839996  down
#  ...                ...         ...   ...
#  2021-10-13  136.289993  134.190002  down
#  2021-10-14  134.789993  136.289993    up
#  2021-10-15  133.610001  134.789993    up
#  2021-10-18  128.990005  133.610001    up
#  2022-08-19  148.054993  128.990005  down
#
#  [1258 rows x 3 columns],
#  'BIIB':                  Close       lag_1 label
#  Date
#  2021-10-20  266.570007  268.130005    up
#  2021-10-21  270.209991  266.570007  down
#  2021-10-22  264.799988  270.209991    up
#  2021-10-25  269.940002  264.799988  down
#  2021-10-26  271.119995  269.940002  down
#  ...                ...         ...   ...
#  2021-10-13  283.649994  284.790009    up
#  2021-10-14  285.260010  283.649994  down
#  2021-10-15  281.190002  285.260010    up
#  2021-10-18  269.730011  281.190002    up
#  2022-08-19  214.770004  269.730011    up
#
#  [1258 rows x 3 columns],
#  'BLCM':              Close  lag_1 label
#  Date
#  2021-10-20  2.2700   2.26  down
#  2021-10-21  2.2300   2.27    up
#  2021-10-22  2.0700   2.23    up
#  2021-10-25  2.0500   2.07    up
#  2021-10-26  1.9900   2.05    up
#  ...            ...    ...   ...
#  2021-10-13  2.7200   2.70  down
#  2021-10-14  2.6900   2.72    up
#  2021-10-15  2.6000   2.69    up
#  2021-10-18  2.5100   2.60    up
#  2022-08-19  1.4336   2.51    up
#
#  [1258 rows x 3 columns],
#  'BLPH':             Close  lag_1 label
#  Date
#  2021-10-20  4.050  4.015  down
#  2021-10-21  3.930  4.050    up
#  2021-10-22  3.840  3.930    up
#  2021-10-25  3.840  3.840  down
#  2021-10-26  3.800  3.840    up
#  ...           ...    ...   ...
#  2021-10-13  3.800  3.890    up
#  2021-10-14  3.890  3.800  down
#  2021-10-15  3.900  3.890  down
#  2021-10-18  4.040  3.900  down
#  2022-08-19  1.435  4.040    up
#
#  [1258 rows x 3 columns],
#  'BLRX':             Close  lag_1 label
#  Date
#  2021-10-20   2.86   2.90    up
#  2021-10-21   3.04   2.86  down
#  2021-10-22   2.88   3.04    up
#  2021-10-25   2.88   2.88  down
#  2021-10-26   2.86   2.88    up
#  ...           ...    ...   ...
#  2021-10-13   2.86   2.63  down
#  2021-10-14   2.95   2.86  down
#  2021-10-15   3.06   2.95  down
#  2021-10-18   2.90   3.06    up
#  2022-08-19   1.68   2.90    up
#
#  [1258 rows x 3 columns],
#  'BLUE':                 Close      lag_1 label
#  Date
#  2021-10-20  13.588083  13.918394    up
#  2021-10-21  13.205959  13.588083    up
#  2021-10-22  13.471503  13.205959  down
#  2021-10-25  13.750000  13.471503  down
#  2021-10-26  13.568653  13.750000    up
#  ...               ...        ...   ...
#  2021-10-13  13.031088  13.231865    up
#  2021-10-14  13.348446  13.031088  down
#  2021-10-15  13.536269  13.348446  down
#  2021-10-18  13.620466  13.536269  down
#  2022-08-19   5.695000  13.620466    up
#
#  [1258 rows x 3 columns],
#  'BMRN':                 Close      lag_1 label
#  Date
#  2021-10-20  75.150002  74.139999  down
#  2021-10-21  75.080002  75.150002    up
#  2021-10-22  73.739998  75.080002    up
#  2021-10-25  73.510002  73.739998    up
#  2021-10-26  73.419998  73.510002    up
#  ...               ...        ...   ...
#  2021-10-13  76.820000  78.629997    up
#  2021-10-14  77.519997  76.820000  down
#  2021-10-15  75.889999  77.519997    up
#  2021-10-18  73.919998  75.889999    up
#  2022-08-19  92.915001  73.919998  down
#
#  [1258 rows x 3 columns],
#  'BPMC':                  Close       lag_1 label
#  Date
#  2021-10-20  102.209999  102.519997    up
#  2021-10-21  100.959999  102.209999    up
#  2021-10-22  102.290001  100.959999  down
#  2021-10-25  102.519997  102.290001  down
#  2021-10-26  103.669998  102.519997  down
#  ...                ...         ...   ...
#  2021-10-13   98.709999   98.750000    up
#  2021-10-14  101.339996   98.709999  down
#  2021-10-15  100.150002  101.339996    up
#  2021-10-18   99.220001  100.150002    up
#  2022-08-19   66.220001   99.220001    up
#
#  [1258 rows x 3 columns],
#  'BTAI':                 Close      lag_1 label
#  Date
#  2021-10-20  28.680000  28.719999    up
#  2021-10-21  29.709999  28.680000  down
#  2021-10-22  29.940001  29.709999  down
#  2021-10-25  29.889999  29.940001    up
#  2021-10-26  30.809999  29.889999  down
#  ...               ...        ...   ...
#  2021-10-13  31.719999  32.279999    up
#  2021-10-14  27.700001  31.719999    up
#  2021-10-15  27.090000  27.700001    up
#  2021-10-18  28.049999  27.090000  down
#  2022-08-19  14.250000  28.049999    up
#
#  [1121 rows x 3 columns],
#  'BTX':             Close  lag_1 label
#  Date
#  2021-10-20   9.73   9.38  down
#  2021-10-21   9.62   9.73    up
#  2021-10-22   9.01   9.62    up
#  2021-10-25   8.95   9.01    up
#  2021-10-26   8.74   8.95    up
#  ...           ...    ...   ...
#  2021-10-13   9.23   9.06  down
#  2021-10-14   9.12   9.23    up
#  2021-10-15   9.15   9.12  down
#  2021-10-18   9.29   9.15  down
#  2022-08-19   0.49   9.29    up
#
#  [1258 rows x 3 columns],
#  'BVXV':             Close  lag_1 label
#  Date
#  2021-10-20   2.39   2.40    up
#  2021-10-21   2.28   2.39    up
#  2021-10-22   2.18   2.28    up
#  2021-10-25   2.26   2.18  down
#  2021-10-26   2.12   2.26    up
#  ...           ...    ...   ...
#  2021-10-13   2.19   2.15  down
#  2021-10-14   2.19   2.19  down
#  2021-10-15   2.21   2.19  down
#  2021-10-18   2.32   2.21  down
#  2022-08-19   1.19   2.32    up
#
#  [1258 rows x 3 columns],
#  'BYSI':                 Close      lag_1 label
#  Date
#  2021-10-20  16.750000  16.660000  down
#  2021-10-21  16.370001  16.750000    up
#  2021-10-22  15.990000  16.370001    up
#  2021-10-25  15.450000  15.990000    up
#  2021-10-26  15.210000  15.450000    up
#  ...               ...        ...   ...
#  2021-10-13  16.709999  15.600000  down
#  2021-10-14  16.840000  16.709999  down
#  2021-10-15  16.549999  16.840000    up
#  2021-10-18  16.129999  16.549999    up
#  2022-08-19   1.500000  16.129999    up
#
#  [1258 rows x 3 columns],
#  'CALA':                 Close      lag_1 label
#  Date
#  2021-10-20  38.400002  38.599998    up
#  2021-10-21  38.400002  38.400002  down
#  2021-10-22  37.400002  38.400002    up
#  2021-10-25  38.000000  37.400002  down
#  2021-10-26  38.200001  38.000000  down
#  ...               ...        ...   ...
#  2021-10-13  41.200001  42.400002    up
#  2021-10-14  41.799999  41.200001  down
#  2021-10-15  40.799999  41.799999    up
#  2021-10-18  40.200001  40.799999    up
#  2022-08-19   4.570000  40.200001    up
#
#  [1258 rows x 3 columns],
#  'CANF':              Close  lag_1 label
#  Date
#  2021-10-20  1.5600   1.56  down
#  2021-10-21  1.5700   1.56  down
#  2021-10-22  1.5300   1.57    up
#  2021-10-25  1.5500   1.53  down
#  2021-10-26  1.5000   1.55    up
#  ...            ...    ...   ...
#  2021-10-13  1.5500   1.56    up
#  2021-10-14  1.5800   1.55  down
#  2021-10-15  1.5500   1.58    up
#  2021-10-18  1.5500   1.55  down
#  2022-08-19  0.8704   1.55    up
#
#  [1258 rows x 3 columns],
#  'CAPR':             Close  lag_1 label
#  Date
#  2021-10-20   4.03   3.96  down
#  2021-10-21   3.99   4.03    up
#  2021-10-22   3.82   3.99    up
#  2021-10-25   3.87   3.82  down
#  2021-10-26   3.88   3.87  down
#  ...           ...    ...   ...
#  2021-10-13   4.12   3.98  down
#  2021-10-14   4.16   4.12  down
#  2021-10-15   3.96   4.16    up
#  2021-10-18   3.89   3.96    up
#  2022-08-19   5.50   3.89  down
#
#  [1258 rows x 3 columns],
#  'CARA':             Close  lag_1 label
#  Date
#  2021-10-20  12.89  12.83  down
#  2021-10-21  12.99  12.89  down
#  2021-10-22  12.70  12.99    up
#  2021-10-25  13.22  12.70  down
#  2021-10-26  14.19  13.22  down
#  ...           ...    ...   ...
#  2021-10-13  13.35  13.74    up
#  2021-10-14  13.34  13.35    up
#  2021-10-15  13.16  13.34    up
#  2021-10-18  12.72  13.16    up
#  2022-08-19  11.04  12.72    up
#
#  [1258 rows x 3 columns],
#  'CASI':             Close  lag_1 label
#  Date
#  2021-10-20  11.20   11.1  down
#  2021-10-21  11.10   11.2    up
#  2021-10-22  10.90   11.1    up
#  2021-10-25  10.70   10.9    up
#  2021-10-26  10.60   10.7    up
#  ...           ...    ...   ...
#  2021-10-13  11.90   11.7  down
#  2021-10-14  11.70   11.9    up
#  2021-10-15  11.50   11.7    up
#  2021-10-18  11.50   11.5  down
#  2022-08-19   3.18   11.5    up
#
#  [1258 rows x 3 columns],
#  'CBAY':             Close  lag_1 label
#  Date
#  2021-10-20   3.98   3.98  down
#  2021-10-21   4.01   3.98  down
#  2021-10-22   3.89   4.01    up
#  2021-10-25   3.81   3.89    up
#  2021-10-26   3.81   3.81  down
#  ...           ...    ...   ...
#  2021-10-13   4.10   4.24    up
#  2021-10-14   4.06   4.10    up
#  2021-10-15   4.01   4.06    up
#  2021-10-18   3.91   4.01    up
#  2022-08-19   3.88   3.91    up
#
#  [1258 rows x 3 columns],
#  'CBIO':             Close  lag_1 label
#  Date
#  2021-10-20  3.510   3.71    up
#  2021-10-21  3.520   3.51  down
#  2021-10-22  3.470   3.52    up
#  2021-10-25  3.420   3.47    up
#  2021-10-26  3.280   3.42    up
#  ...           ...    ...   ...
#  2021-10-13  4.100   4.06  down
#  2021-10-14  4.160   4.10  down
#  2021-10-15  4.000   4.16    up
#  2021-10-18  3.920   4.00    up
#  2022-08-19  1.965   3.92    up
#
#  [1258 rows x 3 columns],
#  'CCXI':                 Close      lag_1 label
#  Date
#  2021-10-20  34.849998  33.650002  down
#  2021-10-21  35.009998  34.849998  down
#  2021-10-22  34.570000  35.009998    up
#  2021-10-25  34.970001  34.570000  down
#  2021-10-26  33.720001  34.970001    up
#  ...               ...        ...   ...
#  2021-10-13  36.910000  36.000000  down
#  2021-10-14  37.080002  36.910000  down
#  2021-10-15  34.470001  37.080002    up
#  2021-10-18  32.430000  34.470001    up
#  2022-08-19  50.930000  32.430000  down
#
#  [1258 rows x 3 columns],
#  'CDMO':                 Close      lag_1 label
#  Date
# ...
#
#  [1258 rows x 3 columns],
#  'UBX':              Close  lag_1 label
#  Date
#  2021-10-20  2.3200   2.37    up
#  2021-10-21  2.2500   2.32    up
#  2021-10-22  2.2400   2.25    up
#  2021-10-25  2.2200   2.24    up
#  2021-10-26  2.2700   2.22  down
#  ...            ...    ...   ...
#  2021-10-13  2.4200   2.43    up
#  2021-10-14  2.3900   2.42    up
#  2021-10-15  2.3500   2.39    up
#  2021-10-18  2.3100   2.35    up
#  2022-08-19  0.6195   2.31    up
#
#  [1082 rows x 3 columns],
#  'URGN':                 Close      lag_1 label
#  Date
#  2021-10-20  16.559999  17.170000    up
#  2021-10-21  16.670000  16.559999  down
#  2021-10-22  17.080000  16.670000  down
#  2021-10-25  16.530001  17.080000    up
#  2021-10-26  16.459999  16.530001    up
#  ...               ...        ...   ...
#  2021-10-13  17.240000  16.940001  down
#  2021-10-14  17.150000  17.240000    up
#  2021-10-15  17.020000  17.150000    up
#  2021-10-18  16.459999  17.020000    up
#  2022-08-19   8.200000  16.459999    up
#
#  [1258 rows x 3 columns],
#  'UTHR':                  Close       lag_1 label
#  Date
#  2021-10-20  192.270004  186.360001  down
#  2021-10-21  190.660004  192.270004    up
#  2021-10-22  191.009995  190.660004  down
#  2021-10-25  191.339996  191.009995  down
#  2021-10-26  190.449997  191.339996    up
#  ...                ...         ...   ...
#  2021-10-13  186.089996  189.929993    up
#  2021-10-14  187.600006  186.089996  down
#  2021-10-15  187.070007  187.600006    up
#  2021-10-18  184.320007  187.070007    up
#  2022-08-19  223.330002  184.320007  down
#
#  [1258 rows x 3 columns],
#  'VBIV':             Close  lag_1 label
#  Date
#  2021-10-20   3.12   3.22    up
#  2021-10-21   3.05   3.12    up
#  2021-10-22   3.04   3.05    up
#  2021-10-25   3.02   3.04    up
#  2021-10-26   2.95   3.02    up
#  ...           ...    ...   ...
#  2021-10-13   3.06   3.04  down
#  2021-10-14   3.07   3.06  down
#  2021-10-15   3.02   3.07    up
#  2021-10-18   3.01   3.02    up
#  2022-08-19   1.04   3.01    up
#
#  [1258 rows x 3 columns],
#  'VBLT':              Close  lag_1 label
#  Date
#  2021-10-20  2.3100   2.21  down
#  2021-10-21  2.3500   2.31  down
#  2021-10-22  2.3500   2.35  down
#  2021-10-25  2.4200   2.35  down
#  2021-10-26  2.3600   2.42    up
#  ...            ...    ...   ...
#  2021-10-13  2.1700   2.16  down
#  2021-10-14  2.2100   2.17  down
#  2021-10-15  2.2300   2.21  down
#  2021-10-18  2.1800   2.23    up
#  2022-08-19  0.2305   2.18    up
#
#  [1258 rows x 3 columns],
#  'VCEL':                 Close      lag_1 label
#  Date
#  2021-10-20  50.730000  52.599998    up
#  2021-10-21  50.570000  50.730000    up
#  2021-10-22  51.290001  50.570000  down
#  2021-10-25  50.970001  51.290001    up
#  2021-10-26  50.820000  50.970001    up
#  ...               ...        ...   ...
#  2021-10-13  49.430000  48.270000  down
#  2021-10-14  50.939999  49.430000  down
#  2021-10-15  50.790001  50.939999    up
#  2021-10-18  52.049999  50.790001  down
#  2022-08-19  30.580000  52.049999    up
#
#  [1258 rows x 3 columns],
#  'VCNX':             Close  lag_1 label
#  Date
#  2021-10-20  1.900   1.92    up
#  2021-10-21  1.900   1.90  down
#  2021-10-22  1.830   1.90    up
#  2021-10-25  1.810   1.83    up
#  2021-10-26  1.910   1.81  down
#  ...           ...    ...   ...
#  2021-10-13  2.100   2.10  down
#  2021-10-14  2.100   2.10  down
#  2021-10-15  2.020   2.10    up
#  2021-10-18  1.940   2.02    up
#  2022-08-19  1.045   1.94    up
#
#  [1014 rows x 3 columns],
#  'VCYT':                 Close      lag_1 label
#  Date
#  2021-10-20  46.450001  46.830002    up
#  2021-10-21  46.529999  46.450001  down
#  2021-10-22  46.400002  46.529999    up
#  2021-10-25  45.910000  46.400002    up
#  2021-10-26  46.360001  45.910000  down
#  ...               ...        ...   ...
#  2021-10-13  43.849998  43.230000  down
#  2021-10-14  45.099998  43.849998  down
#  2021-10-15  45.160000  45.099998  down
#  2021-10-18  45.150002  45.160000    up
#  2022-08-19  21.860001  45.150002    up
#
#  [1258 rows x 3 columns],
#  'VKTX':             Close  lag_1 label
#  Date
#  2021-10-20   5.81   5.84    up
#  2021-10-21   5.70   5.81    up
#  2021-10-22   5.76   5.70  down
#  2021-10-25   5.70   5.76    up
#  2021-10-26   5.85   5.70  down
#  ...           ...    ...   ...
#  2021-10-13   6.18   6.16  down
#  2021-10-14   6.15   6.18    up
#  2021-10-15   6.01   6.15    up
#  2021-10-18   5.86   6.01    up
#  2022-08-19   3.64   5.86    up
#
#  [1258 rows x 3 columns],
#  'VNDA':                 Close      lag_1 label
#  Date
#  2021-10-20  17.809999  17.760000  down
#  2021-10-21  18.040001  17.809999  down
#  2021-10-22  18.299999  18.040001  down
#  2021-10-25  18.150000  18.299999    up
#  2021-10-26  18.000000  18.150000    up
#  ...               ...        ...   ...
#  2021-10-13  18.160000  18.120001  down
#  2021-10-14  18.340000  18.160000  down
#  2021-10-15  18.410000  18.340000  down
#  2021-10-18  18.059999  18.410000    up
#  2022-08-19  10.410000  18.059999    up
#
#  [1258 rows x 3 columns],
#  'VRCA':             Close  lag_1 label
#  Date
#  2021-10-20  12.99  12.49  down
#  2021-10-21  12.60  12.99    up
#  2021-10-22  12.77  12.60  down
#  2021-10-25  12.41  12.77    up
#  2021-10-26  12.83  12.41  down
#  ...           ...    ...   ...
#  2021-10-13  12.65  12.44  down
#  2021-10-14  12.84  12.65  down
#  2021-10-15  13.36  12.84  down
#  2021-10-18  12.39  13.36    up
#  2022-08-19   3.55  12.39    up
#
#  [1052 rows x 3 columns],
#  'VRNA':             Close  lag_1 label
#  Date
#  2021-10-20   4.98   5.02    up
#  2021-10-21   5.05   4.98  down
#  2021-10-22   4.98   5.05    up
#  2021-10-25   5.11   4.98  down
#  2021-10-26   5.25   5.11  down
#  ...           ...    ...   ...
#  2021-10-13   4.86   4.53  down
#  2021-10-14   5.04   4.86  down
#  2021-10-15   5.06   5.04  down
#  2021-10-18   5.14   5.06  down
#  2022-08-19  12.45   5.14  down
#
#  [1258 rows x 3 columns],
#  'VRTX':                  Close       lag_1 label
#  Date
#  2021-10-20  185.490005  185.410004  down
#  2021-10-21  187.089996  185.490005  down
#  2021-10-22  183.520004  187.089996    up
#  2021-10-25  184.990005  183.520004  down
#  2021-10-26  184.070007  184.990005    up
#  ...                ...         ...   ...
#  2021-10-13  181.339996  180.210007  down
#  2021-10-14  181.899994  181.339996  down
#  2021-10-15  181.770004  181.899994    up
#  2021-10-18  180.800003  181.770004    up
#  2022-08-19  295.255005  180.800003  down
#
#  [1258 rows x 3 columns],
#  'VSTM':             Close  lag_1 label
#  Date
#  2021-10-20   2.67   2.69    up
#  2021-10-21   2.61   2.67    up
#  2021-10-22   2.55   2.61    up
#  2021-10-25   2.59   2.55  down
#  2021-10-26   2.61   2.59  down
#  ...           ...    ...   ...
#  2021-10-13   2.75   2.73  down
#  2021-10-14   2.75   2.75  down
#  2021-10-15   2.76   2.75  down
#  2021-10-18   2.64   2.76    up
#  2022-08-19   1.22   2.64    up
#
#  [1258 rows x 3 columns],
#  'VTGN':             Close  lag_1 label
#  Date
#  2021-10-20  2.360   2.37    up
#  2021-10-21  2.340   2.36    up
#  2021-10-22  2.310   2.34    up
#  2021-10-25  2.260   2.31    up
#  2021-10-26  2.300   2.26  down
#  ...           ...    ...   ...
#  2021-10-13  2.490   2.51    up
#  2021-10-14  2.500   2.49  down
#  2021-10-15  2.390   2.50    up
#  2021-10-18  2.300   2.39    up
#  2022-08-19  0.207   2.30    up
#
#  [1258 rows x 3 columns],
#  'VTVT':             Close  lag_1 label
#  Date
#  2021-10-20   1.47   1.47  down
#  2021-10-21   1.44   1.47    up
#  2021-10-22   1.40   1.44    up
#  2021-10-25   1.43   1.40  down
#  2021-10-26   1.42   1.43    up
#  ...           ...    ...   ...
#  2021-10-13   1.52   1.51  down
#  2021-10-14   1.50   1.52    up
#  2021-10-15   1.47   1.50    up
#  2021-10-18   1.44   1.47    up
#  2022-08-19   1.25   1.44    up
#
#  [1258 rows x 3 columns],
#  'VXRT':             Close  lag_1 label
#  Date
#  2021-10-20   6.90   7.05    up
#  2021-10-21   6.88   6.90    up
#  2021-10-22   6.74   6.88    up
#  2021-10-25   6.87   6.74  down
#  2021-10-26   6.84   6.87    up
#  ...           ...    ...   ...
#  2021-10-13   6.89   6.76  down
#  2021-10-14   7.20   6.89  down
#  2021-10-15   6.94   7.20    up
#  2021-10-18   6.89   6.94    up
#  2022-08-19   3.80   6.89    up
#
#  [1258 rows x 3 columns],
#  'VYGR':             Close  lag_1 label
#  Date
#  2021-10-20   4.26   4.59    up
#  2021-10-21   3.91   4.26    up
#  2021-10-22   3.79   3.91    up
#  2021-10-25   3.88   3.79  down
#  2021-10-26   3.72   3.88    up
#  ...           ...    ...   ...
#  2021-10-13   4.53   4.61    up
#  2021-10-14   4.40   4.53    up
#  2021-10-15   4.10   4.40    up
#  2021-10-18   4.55   4.10  down
#  2022-08-19   6.00   4.55  down
#
#  [1258 rows x 3 columns],
#  'WVE':              Close  lag_1 label
#  Date
#  2021-10-20  4.4900   4.69    up
#  2021-10-21  4.3900   4.49    up
#  2021-10-22  4.3400   4.39    up
#  2021-10-25  4.4000   4.34  down
#  2021-10-26  4.3900   4.40    up
#  ...            ...    ...   ...
#  2021-10-13  4.7200   4.74    up
#  2021-10-14  4.7200   4.72  down
#  2021-10-15  5.1500   4.72  down
#  2021-10-18  4.6300   5.15    up
#  2022-08-19  3.3057   4.63    up
#
#  [1258 rows x 3 columns],
#  'XBIO':              Close  lag_1 label
#  Date
#  2021-10-20  1.7600  1.760  down
#  2021-10-21  1.8000  1.760  down
#  2021-10-22  1.6950  1.800    up
#  2021-10-25  1.6900  1.695    up
#  2021-10-26  1.6800  1.690    up
#  ...            ...    ...   ...
#  2021-10-13  1.8600  1.910    up
#  2021-10-14  1.8700  1.860  down
#  2021-10-15  1.8000  1.870    up
#  2021-10-18  1.7100  1.800    up
#  2022-08-19  0.8037  1.710    up
#
#  [1258 rows x 3 columns],
#  'XBIT':              Close  lag_1 label
#  Date
#  2021-10-20  13.800  13.40  down
#  2021-10-21  13.990  13.80  down
#  2021-10-22  14.080  13.99  down
#  2021-10-25  14.340  14.08  down
#  2021-10-26  14.550  14.34  down
#  ...            ...    ...   ...
#  2021-10-13  12.920  12.78  down
#  2021-10-14  13.130  12.92  down
#  2021-10-15  13.210  13.13  down
#  2021-10-18  12.990  13.21    up
#  2022-08-19   4.705  12.99    up
#
#  [1258 rows x 3 columns],
#  'XENE':                 Close      lag_1 label
#  Date
#  2021-10-20  30.350000  29.809999  down
#  2021-10-21  30.629999  30.350000  down
#  2021-10-22  30.860001  30.629999  down
#  2021-10-25  30.730000  30.860001    up
#  2021-10-26  30.570000  30.730000    up
#  ...               ...        ...   ...
#  2021-10-13  31.980000  31.959999  down
#  2021-10-14  32.959999  31.980000  down
#  2021-10-15  33.660000  32.959999  down
#  2021-10-18  30.719999  33.660000    up
#  2022-08-19  37.169998  30.719999  down
#
#  [1258 rows x 3 columns],
#  'XERS':             Close  lag_1 label
#  Date
#  2021-10-20  2.000   1.95  down
#  2021-10-21  1.970   2.00    up
#  2021-10-22  1.820   1.97    up
#  2021-10-25  1.920   1.82  down
#  2021-10-26  1.870   1.92    up
#  ...           ...    ...   ...
#  2021-10-13  2.040   2.11    up
#  2021-10-14  2.010   2.04    up
#  2021-10-15  2.000   2.01    up
#  2021-10-18  1.870   2.00    up
#  2022-08-19  1.805   1.87    up
#
#  [1048 rows x 3 columns],
#  'XNCR':                 Close      lag_1 label
#  Date
#  2021-10-20  38.220001  38.090000  down
#  2021-10-21  38.720001  38.220001  down
#  2021-10-22  39.240002  38.720001  down
#  2021-10-25  39.020000  39.240002    up
#  2021-10-26  38.820000  39.020000    up
#  ...               ...        ...   ...
#  2021-10-13  38.689999  37.939999  down
#  2021-10-14  38.849998  38.689999  down
#  2021-10-15  38.470001  38.849998    up
#  2021-10-18  37.240002  38.470001    up
#  2022-08-19  29.530001  37.240002    up
#
#  [1258 rows x 3 columns],
#  'XOMA':                 Close      lag_1 label
#  Date
#  2021-10-20  23.879999  24.219999    up
#  2021-10-21  23.670000  23.879999    up
#  2021-10-22  24.709999  23.670000  down
#  2021-10-25  23.820000  24.709999    up
#  2021-10-26  23.600000  23.820000    up
#  ...               ...        ...   ...
#  2021-10-13  24.730000  25.799999    up
#  2021-10-14  25.500000  24.730000  down
#  2021-10-15  25.790001  25.500000  down
#  2021-10-18  23.360001  25.790001    up
#  2022-08-19  18.300100  23.360001    up
#
#  [1258 rows x 3 columns],
#  'XTLB':             Close  lag_1 label
#  Date
#  2021-10-20  4.030   4.00  down
#  2021-10-21  3.810   4.03    up
#  2021-10-22  3.740   3.81    up
#  2021-10-25  3.810   3.74  down
#  2021-10-26  3.760   3.81    up
#  ...           ...    ...   ...
#  2021-10-13  4.010   4.04    up
#  2021-10-14  3.950   4.01    up
#  2021-10-15  3.930   3.95    up
#  2021-10-18  3.980   3.93  down
#  2022-08-19  1.739   3.98    up
#
#  [1258 rows x 3 columns],
#  'XXII':              Close  lag_1 label
#  Date
#  2021-10-20  2.9200   2.90  down
#  2021-10-21  2.9900   2.92  down
#  2021-10-22  2.8900   2.99    up
#  2021-10-25  2.9600   2.89  down
#  2021-10-26  2.9600   2.96  down
#  ...            ...    ...   ...
#  2021-10-13  2.9400   2.94  down
#  2021-10-14  2.9500   2.94  down
#  2021-10-15  2.9000   2.95    up
#  2021-10-18  2.8900   2.90    up
#  2022-08-19  1.4652   2.89    up
#
#  [1258 rows x 3 columns],
#  'YMAB':                 Close      lag_1 label
#  Date
#  2021-10-20  26.139999  26.459999    up
#  2021-10-21  26.270000  26.139999  down
#  2021-10-22  26.549999  26.270000  down
#  2021-10-25  25.910000  26.549999    up
#  2021-10-26  25.450001  25.910000    up
#  ...               ...        ...   ...
#  2021-10-13  27.490000  27.320000  down
#  2021-10-14  27.879999  27.490000  down
#  2021-10-15  26.680000  27.879999    up
#  2021-10-18  26.530001  26.680000    up
#  2022-08-19  17.389999  26.530001    up
#
#  [984 rows x 3 columns],
#  'ZEAL':                 Close      lag_1 label
#  Date
#  2021-10-20  31.059999  31.730000    up
#  2021-10-21  31.059999  31.059999  down
#  2021-10-22  32.275002  31.059999  down
#  2021-10-25  32.200001  32.275002    up
#  2021-10-26  31.730000  32.200001    up
#  ...               ...        ...   ...
#  2021-10-13  30.618999  28.736000  down
#  2021-10-14  30.618999  30.618999  down
#  2021-10-15  30.601999  30.618999    up
#  2021-10-18  31.990000  30.601999  down
#  2022-08-19  19.030001  31.990000    up
#
#  [1258 rows x 3 columns],
#  'ZLAB':                  Close       lag_1 label
#  Date
#  2021-10-20   99.730003  101.220001    up
#  2021-10-21   99.720001   99.730003    up
#  2021-10-22  100.750000   99.720001  down
#  2021-10-25  104.000000  100.750000  down
#  2021-10-26  105.209999  104.000000  down
#  ...                ...         ...   ...
#  2021-10-13  102.110001   99.529999  down
#  2021-10-14  102.190002  102.110001  down
#  2021-10-15  102.000000  102.190002    up
#  2021-10-18   99.180000  102.000000    up
#  2022-08-19   41.980000   99.180000    up
#
#  [1237 rows x 3 columns],
#  'ZYME':                 Close      lag_1 label
#  Date
#  2021-10-20  23.100000  22.799999  down
#  2021-10-21  23.360001  23.100000  down
#  2021-10-22  23.000000  23.360001    up
#  2021-10-25  23.730000  23.000000  down
#  2021-10-26  23.200001  23.730000    up
#  ...               ...        ...   ...
#  2021-10-13  25.290001  25.540001    up
#  2021-10-14  24.740000  25.290001    up
#  2021-10-15  25.940001  24.740000  down
#  2021-10-18  24.010000  25.940001    up
#  2022-08-19   6.390000  24.010000    up
#
#  [1258 rows x 3 columns],
#  'ZYNE':             Close  lag_1 label
#  Date
#  2021-10-20   4.02   4.02  down
#  2021-10-21   4.13   4.02  down
#  2021-10-22   3.87   4.13    up
#  2021-10-25   3.85   3.87    up
#  2021-10-26   3.76   3.85    up
#  ...           ...    ...   ...
#  2021-10-13   4.12   4.11  down
#  2021-10-14   4.13   4.12  down
#  2021-10-15   4.06   4.13    up
#  2021-10-18   3.90   4.06    up
#  2022-08-19   1.25   3.90    up
#
#  [1258 rows x 3 columns]}

# %% [markdown]
# ## Cost Function
# $$ J\big(w, b\big) = -\frac{1}{m}\displaystyle\sum_{i=1}^{m}\big(y^{(i)}log\big(f_{w, b}(x^{(i)})\big) + \big(1 - y^{(i)}\big)\big(log\big(1 - f_{w, b}(x^{(i)})\big)\big)  $$
# Regularized:
# $$ J\big(w, b\big) = -\frac{1}{m}\displaystyle\sum_{i=1}^{m}\big(y^{(i)}log\big(f_{w, b}(x^{(i)})\big) + \big(1 - y^{(i)}\big)\big(log\big(1 - f_{w, b}(x^{(i)})\big)\big) + \frac{\lambda}{2m}\displaystyle\sum_{j=1}^{n}w_{j}^{2} $$

# %%
np.random.seed(1)
X_tmp = np.random.rand(5,6)
y_tmp = np.array([0,1,0,1,0])
w_tmp = np.random.rand(X_tmp.shape[1]).reshape(-1,) * 2
b_tmp = 0.5
lambda_tmp = 0.7
cost_tmp = compute_cost_logistic_regression(X_tmp, y_tmp, w_tmp, b_tmp, lambda_tmp)

print("Regularized cost:", cost_tmp)
# Out:
# Regularized cost: 2.0543906339569977

# %% [markdown]
# ## Gradient Descent
# $$ w_{j} = w_{j} - \alpha\frac{1}{m}\displaystyle\sum_{i=1}^{m}\big(f_{w,b}\big(x^{(i)}\big)-y^{(i)}\big)x_{j}^{(i)} + \frac{\lambda}{m}w_{j} $$
# $$ b = b - \alpha\frac{1}{m}\displaystyle\sum_{i=1}^{m}\big(f_{w,b}\big(x^{(i)}\big)-y^{(i)}\big) $$

# %%
np.random.seed(1)
X_tmp = np.random.rand(5,3)
y_tmp = np.array([0,1,0,1,0])
w_tmp = np.random.rand(X_tmp.shape[1])
b_tmp = 0.5
lambda_tmp = 0.7
dj_dw_tmp, dj_db_tmp = compute_gradient_logistic_regression(X_tmp, y_tmp, w_tmp, b_tmp, lambda_tmp)

print(f"dj_db: {dj_db_tmp}", )
print(f"Regularized dj_dw:\n {dj_dw_tmp.tolist()}", )
# Out:
# dj_db: 0.341798994972791
# Regularized dj_dw:
#  [0.17380012933994293, 0.3200750788156695, 0.10776313396851497]

# %%
num_iters = 10000
alpha = 5.0e-5
w_final, b_final = gradient_descent(X_tmp, y_tmp, w_tmp, b_tmp, alpha, lambda_tmp, num_iters)
print(f"Final w: {w_final.tolist()}", )
print(f"Final b:\n {b_final}", )
# Out:
# Final w: [0.6403681057234213, 0.34577216203443556, 0.54508714113052]
# Final b:
#  -0.9243437114863322

# %%
cost_final = compute_cost_logistic_regression(X_tmp, y_tmp, w_final, b_final, lambda_tmp)
print(f'Cost:\n{cost_final}')
# Out:
# Cost:
# 0.7098603640827459
